# %%
# import glob
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import matplotlib as mpl

import cv2

mpl.rcParams['figure.figsize'] = (10,10)

# %%
# !ls
# Out:
# chessboard-data-exploration.ipynb	raw
# chessboard-perspective-transform.ipynb	sample-skew-top-down.jpeg

# %%
def img_reshape(img):
    img.convert('RGB')
    img = np.asarray(img)
    return img

# %%
img = img_reshape(Image.open("sample-skew-top-down.jpeg"))

# %%
plt.imshow(img)

# %%
found, corners = cv2.findChessboardCorners(img, (8, 8))

# %%
print(found)
# Out:
# False

# %% [markdown]
# ### Need to do preprocessing on image before calling findChessboardCorners
